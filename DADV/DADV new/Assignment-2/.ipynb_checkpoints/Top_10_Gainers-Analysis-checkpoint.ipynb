# %%
import time
import csv
import pandas as pd

dfEquity = pd.read_csv("E:\\Spec\\Data-Science\\DADV\\DADV new\\Assignment-2\\Equity.csv")

security_numbers = dfEquity["Security Code"].tolist()

final_dict = {}

no_years = 3
no_months = 0

for each in security_numbers:
    
    temp_file = str(each) + ".csv"
    
    url = "E:\\Spec\\Data-Science\\DADV\\DADV new\\Assignment-2\\" + temp_file
    
    df = pd.read_csv(url)

    month_dict = {"January" : 1, "February" : 2, "March" : 3, "April" : 4, "May" : 5, "June" : 6,"July" : 7, "August" : 8, "September" : 9, "October" : 10, "November" : 11, "December" : 12}
    
    Month_list = []
    Year_list = []
    Day_list = []
    
    for each1 in df["Date"].values:
        list1 = each1.split("-")
        Day_list.append(int(list1[0]))
        Month_list.append(month_dict[list1[1]])
        Year_list.append(int(list1[2]))        

    df["Day"] = Day_list
    df["Month"] = Month_list
    df["Year"] = Year_list
    
    last_day = df.iloc[0,:]
    
    first_day = df.iloc[0,:]
    
    to_year = last_day["Year"] - no_years 
    to_month = last_day["Month"] - no_months + 1

    for i in range(0, len(df)):
        
        temp_day = df.iloc[i,:]
        
        if (temp_day["Year"] == to_year) & (temp_day["Month"] < to_month):
            break
        elif temp_day["Year"] < to_year:
            break
        else:
            first_day = temp_day
    
    gain = (last_day["Close Price"] / first_day["Close Price"]) - 1
  
    gain_per = gain * 100
    
    final_dict[each] = gain_per
    
    

final_dict = sorted(final_dict.items(), key = lambda x: (-x[1], x[0]),reverse=False)

count = 0

Top_10_List = []

for each in final_dict:
    count = count + 1
    Top_10_List.append(each)
    if(count == 10):
        break
    
print(Top_10_List)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-06e4f8833de9> in <module>
#      18     url = "E:\\Spec\\Data-Science\\DADV\\Assignment-2\\" + temp_file
#      19
# ---> 20     df = pd.read_csv(url)
#      21
#      22     month_dict = {"January" : 1, "February" : 2, "March" : 3, "April" : 4, "May" : 5, "June" : 6,"July" : 7, "August" : 8, "September" : 9, "October" : 10, "November" : 11, "December" : 12}
#
# c:\users\hp\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     603     kwds.update(kwds_defaults)
#     604
# --> 605     return _read(filepath_or_buffer, kwds)
#     606
#     607
#
# c:\users\hp\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(filepath_or_buffer, **kwds)
#     458
#     459     if chunksize or iterator:
#
# c:\users\hp\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     812             self.options["has_index_names"] = kwds["has_index_names"]
#     813
# --> 814         self._engine = self._make_engine(self.engine)
#     815
#     816     def close(self):
#
# c:\users\hp\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1043             )
#    1044         # error: Too many arguments for "ParserBase"
# -> 1045         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1046
#    1047     def _failover_to_python(self):
#
# c:\users\hp\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1860
#    1861         # open handles
# -> 1862         self._open_handles(src, kwds)
#    1863         assert self.handles is not None
#    1864         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# c:\users\hp\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\parsers.py in _open_handles(self, src, kwds)
#    1355         Let the readers open IOHanldes after they are done with their potential raises.
#    1356         """
# -> 1357         self.handles = get_handle(
#    1358             src,
#    1359             "r",
#
# c:\users\hp\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'E:\\Spec\\Data-Science\\DADV\\Assignment-2\\500003.csv'
